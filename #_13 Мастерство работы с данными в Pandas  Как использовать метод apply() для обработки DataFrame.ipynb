# %%
# task 6
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

salary_ = count_df.loc[count_df.loc[:, 'first_name'] == 'Chalmers', "salary"]

count_df.loc[count_df.loc[:, 'first_name'] == 'Chalmers', "salary"] = salary_ * 1.1
count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def add_10_per(x):
    if x.first_name == "Chalmers":
        x.salary = x.salary * 1.1
        
    return x    

count_df.apply(add_10_per, axis=1)
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
# task 7

import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def add_10_per(x):
    x.salary = '$' + str(x.salary)
    return x    

count_df.apply(add_10_per, axis=1)
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def add_10_per(x):
    x.salary = str(x.salary).lstrip('$')
    return x    

count_df.apply(add_10_per, axis=1)
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
# task 8

import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def add_10_per(x):
    x.salary = '$' + str(x.salary)
    return x    

count_df = count_df.apply(add_10_per, axis=1)

count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
# task 8

import pandas as pd
import numpy as np

def add_10_per(row):
    try:
        money_str = row['salary'][1:]
        money = float(money_str)
        
        if money < 100000:
            age = np.random.randint(18, 35)
        else:
            age = np.random.randint(35, 75)
                
        row["age"] = age
        
        return row
    except ValueError as _ex:
        print(f'error prosessing row:{row}')
        return np.nan

count_df_new = count_df.apply(add_10_per, axis=1)

count_df_new
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   34
# 1              2         My  Brackenridge   65
# 2              3   Chalmers       Puffett   59
# 3              4     Burton      Trubshaw   42
# 4              5    Delcine      Palatini   31
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   40
# 996          997    Lyndsay       McVicar   24
# 997          998      Casar        Ghiron   26
# 998          999    Aloisia        Jerome   28
# 999         1000      Kalli       Bramsen   27
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...
