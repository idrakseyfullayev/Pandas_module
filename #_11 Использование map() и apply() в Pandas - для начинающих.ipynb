# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
count_df
# Out:
#      employee_id first_name  ...  salary   hire_date
# 0              1    Juanita  ...   67642  12/10/2012
# 1              2         My  ...  139070   5/24/2010
# 2              3   Chalmers  ...  119215   11/8/2011
# 3              4     Burton  ...  132201   10/4/2015
# 4              5    Delcine  ...   81064    7/9/2018
# ..           ...        ...  ...     ...         ...
# 995          996     Ardisj  ...  136192   1/13/2015
# 996          997    Lyndsay  ...   81586    8/9/2018
# 997          998      Casar  ...   37731  12/10/2020
# 998          999    Aloisia  ...   81738   7/31/2019
# 999         1000      Kalli  ...   28024   5/31/2011
#
# [1000 rows x 10 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
count_df.employee_id
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: employee_id, Length: 1000, dtype: int64

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.employee_id.describe()
description_numerical
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: employee_id, dtype: float64

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.employee_id.describe().apply("{0:.0f}".format)
description_numerical
# Out:
# count    1000
# mean      500
# std       289
# min         1
# 25%       251
# 50%       500
# 75%       750
# max      1000
# Name: employee_id, dtype: object

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.email.describe()
description_numerical
# Out:
# count                     1000
# unique                    1000
# top       jshurrock0@cisco.com
# freq                         1
# Name: email, dtype: object

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
description_numerical
# Out:
# count        1000
# unique        939
# top       Othelia
# freq            3
# Name: first_name, dtype: object

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
count_df.sort_values('first_name')
# Out:
#      employee_id first_name  ...  salary  hire_date
# 79            80      Abbey  ...   97926  9/19/2022
# 674          675       Abbi  ...   45023  8/26/2014
# 272          273    Abigael  ...   39350   4/4/2016
# 402          403    Abraham  ...   33019   7/6/2013
# 460          461       Adda  ...   42977  8/28/2021
# ..           ...        ...  ...     ...        ...
# 486          487  Zechariah  ...   50420  5/11/2010
# 430          431      Zenia  ...   33524  2/16/2019
# 394          395     Zilvia  ...   36631  7/26/2018
# 134          135       Zita  ...   33249   9/5/2017
# 408          409       Zola  ...  111452  4/24/2019
#
# [1000 rows x 10 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
count_df.sort_values('first_name', inplace=True)
count_df.head(50)
# Out:
#      employee_id first_name  ...  salary   hire_date
# 79            80      Abbey  ...   97926   9/19/2022
# 674          675       Abbi  ...   45023   8/26/2014
# 272          273    Abigael  ...   39350    4/4/2016
# 402          403    Abraham  ...   33019    7/6/2013
# 460          461       Adda  ...   42977   8/28/2021
# 423          424   Adelheid  ...   26653    5/3/2022
# 817          818     Adelle  ...  108026   5/10/2017
# 76            77      Adham  ...   81702   5/21/2011
# 615          616        Adi  ...  132205   5/17/2018
# 407          408     Adiana  ...   58691   7/31/2012
# 294          295      Adore  ...   33232   10/1/2011
# 576          577      Adria  ...   53870   2/27/2021
# 212          213    Adriano  ...   72289   7/14/2018
# 228          229       Aggi  ...   67223    5/5/2013
# 522          523    Agnella  ...   30926   12/9/2010
# 481          482      Agnes  ...  128512    3/7/2018
# 610          611    Agnesse  ...  135815  10/29/2019
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
count_df.sort_values('first_name', inplace=False)
count_df
# Out:
#      employee_id first_name  ...  salary   hire_date
# 0              1    Juanita  ...   67642  12/10/2012
# 1              2         My  ...  139070   5/24/2010
# 2              3   Chalmers  ...  119215   11/8/2011
# 3              4     Burton  ...  132201   10/4/2015
# 4              5    Delcine  ...   81064    7/9/2018
# ..           ...        ...  ...     ...         ...
# 995          996     Ardisj  ...  136192   1/13/2015
# 996          997    Lyndsay  ...   81586    8/9/2018
# 997          998      Casar  ...   37731  12/10/2020
# 998          999    Aloisia  ...   81738   7/31/2019
# 999         1000      Kalli  ...   28024   5/31/2011
#
# [1000 rows x 10 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.first_name.unique()
# Out:
# array(['Juanita', 'My', 'Chalmers', 'Burton', 'Delcine', 'Rubina',
#        'Haven', 'Ardys', 'Prescott', 'Jannelle', 'Ariel', 'Timothee',
#        'Sheela', 'Alva', 'Saleem', 'Karel', 'Lauralee', 'Webb', 'Gerardo',
#        'Welbie', 'Bobinette', 'Andreana', 'Nanny', 'Bonnie', 'Lenore',
#        'Othello', 'Luella', 'Frazer', 'Creigh', 'Selie', 'Ibby',
#        'Blondelle', 'Salmon', 'Eleanore', 'Harlene', 'Roseanna',
#        'Nicolette', 'Gracia', 'Goldy', 'Antoni', 'Jamal', 'Scot',
#        'Glynis', 'Boy', 'Randie', 'Stafani', 'Veronika', 'Petr', 'Parry',
#        'Lydon', 'Eva', 'Ammamaria', 'Erasmus', 'Tobe', 'Tymon',
#        'Cindelyn', 'Frazier', 'Zabrina', 'Koralle', 'Nani', 'Claybourne',
#        'Emmalee', 'Farly', 'Bettina', 'Chrystel', 'Anabel', 'Demott',
#        'Kit', 'Pavel', 'Huberto', 'Leann', 'Alfredo', 'Aridatha', 'Saxe',
#        'Ronny', 'Jandy', 'Adham', 'Melonie', 'Teriann', 'Abbey', 'Elaina',
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
len(count_df.first_name.unique())
# Out:
# 939

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.first_name.nunique()
# Out:
# 939

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.loc[count_df.first_name.duplicated(), 'first_name':'first_name']
# Out:
#          first_name
# 108        Salvador
# 139         Frazier
# 207          Miller
# 213  Helenelizabeth
# 240            Nani
# ..              ...
# 974          Brynne
# 976              My
# 988            Lina
# 989             Nat
# 991          Paulie
#
# [61 rows x 1 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.loc[count_df.first_name.duplicated(), 'first_name':'first_name'].head(60)
# Out:
#          first_name
# 108        Salvador
# 139         Frazier
# 207          Miller
# 213  Helenelizabeth
# 240            Nani
# 322         Olympie
# 327         Lynnell
# 328           Jamal
# 389         Othelia
# 429           Rania
# 451        Forester
# 456           Kitty
# 466           Paton
# 467          Norman
# 469           Lucho
# 489           Irena
# 497         Salomon
# 517          Saleem
# 524          Shanan
# 530           Scott
# 542         Melonie
# 549        Wilmette
# 554          Anabel
# 562           Loren
# 573        Basilius
# 610         Agnesse
# 617            Dore
# 620          Kamila
# 622           Ahmad
# 658            Elna
# 688        Carolann
# 698     Archambault
# 731         Modesta
# 752          Dulsea
# 757         Leonora
# 762           Henka
# 780           Richy
# 782         Jenelle
# 787           Naomi
# 815          Vergil
# 822          Ashlee
# 837          Gladys
# 850          Bridie
# 851        Marietta
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
arr = count_df.loc[count_df.first_name.duplicated(), 'first_name':'first_name']
len(arr)
# Out:
# 61

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.loc[count_df.first_name.duplicated(), 'first_name':'first_name']
# Out:
#          first_name
# 108        Salvador
# 139         Frazier
# 207          Miller
# 213  Helenelizabeth
# 240            Nani
# ..              ...
# 974          Brynne
# 976              My
# 988            Lina
# 989             Nat
# 991          Paulie
#
# [61 rows x 1 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.loc[count_df.first_name.duplicated(keep=False), 'first_name':'first_name']
# Out:
#     first_name
# 1           My
# 14      Saleem
# 40       Jamal
# 56     Frazier
# 59        Nani
# ..         ...
# 974     Brynne
# 976         My
# 988       Lina
# 989        Nat
# 991     Paulie
#
# [121 rows x 1 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
arr = count_df.loc[count_df.first_name.duplicated(keep=False), 'first_name':'first_name']
len(arr)
# Out:
# 121

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.drop_duplicates('first_name')
# Out:
#      employee_id first_name  ...  salary   hire_date
# 0              1    Juanita  ...   67642  12/10/2012
# 1              2         My  ...  139070   5/24/2010
# 2              3   Chalmers  ...  119215   11/8/2011
# 3              4     Burton  ...  132201   10/4/2015
# 4              5    Delcine  ...   81064    7/9/2018
# ..           ...        ...  ...     ...         ...
# 995          996     Ardisj  ...  136192   1/13/2015
# 996          997    Lyndsay  ...   81586    8/9/2018
# 997          998      Casar  ...   37731  12/10/2020
# 998          999    Aloisia  ...   81738   7/31/2019
# 999         1000      Kalli  ...   28024   5/31/2011
#
# [939 rows x 10 columns]

# %%
count_df
# Out:
#      employee_id first_name  ...  salary   hire_date
# 0              1    Juanita  ...   67642  12/10/2012
# 1              2         My  ...  139070   5/24/2010
# 2              3   Chalmers  ...  119215   11/8/2011
# 3              4     Burton  ...  132201   10/4/2015
# 4              5    Delcine  ...   81064    7/9/2018
# ..           ...        ...  ...     ...         ...
# 995          996     Ardisj  ...  136192   1/13/2015
# 996          997    Lyndsay  ...   81586    8/9/2018
# 997          998      Casar  ...   37731  12/10/2020
# 998          999    Aloisia  ...   81738   7/31/2019
# 999         1000      Kalli  ...   28024   5/31/2011
#
# [1000 rows x 10 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60)
# Out:
#      employee_id  first_name  ...  salary   hire_date
# 79            80       Abbey  ...   97926   9/19/2022
# 674          675        Abbi  ...   45023   8/26/2014
# 272          273     Abigael  ...   39350    4/4/2016
# 402          403     Abraham  ...   33019    7/6/2013
# 460          461        Adda  ...   42977   8/28/2021
# 423          424    Adelheid  ...   26653    5/3/2022
# 817          818      Adelle  ...  108026   5/10/2017
# 76            77       Adham  ...   81702   5/21/2011
# 615          616         Adi  ...  132205   5/17/2018
# 407          408      Adiana  ...   58691   7/31/2012
# 294          295       Adore  ...   33232   10/1/2011
# 576          577       Adria  ...   53870   2/27/2021
# 212          213     Adriano  ...   72289   7/14/2018
# 228          229        Aggi  ...   67223    5/5/2013
# 522          523     Agnella  ...   30926   12/9/2010
# 481          482       Agnes  ...  128512    3/7/2018
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).drop_duplicates('first_name')
# Out:
#      employee_id  first_name  ...  salary   hire_date
# 79            80       Abbey  ...   97926   9/19/2022
# 674          675        Abbi  ...   45023   8/26/2014
# 272          273     Abigael  ...   39350    4/4/2016
# 402          403     Abraham  ...   33019    7/6/2013
# 460          461        Adda  ...   42977   8/28/2021
# 423          424    Adelheid  ...   26653    5/3/2022
# 817          818      Adelle  ...  108026   5/10/2017
# 76            77       Adham  ...   81702   5/21/2011
# 615          616         Adi  ...  132205   5/17/2018
# 407          408      Adiana  ...   58691   7/31/2012
# 294          295       Adore  ...   33232   10/1/2011
# 576          577       Adria  ...   53870   2/27/2021
# 212          213     Adriano  ...   72289   7/14/2018
# 228          229        Aggi  ...   67223    5/5/2013
# 522          523     Agnella  ...   30926   12/9/2010
# 481          482       Agnes  ...  128512    3/7/2018
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).drop_duplicates('first_name', keep='first')
# Out:
#      employee_id  first_name  ...  salary   hire_date
# 79            80       Abbey  ...   97926   9/19/2022
# 674          675        Abbi  ...   45023   8/26/2014
# 272          273     Abigael  ...   39350    4/4/2016
# 402          403     Abraham  ...   33019    7/6/2013
# 460          461        Adda  ...   42977   8/28/2021
# 423          424    Adelheid  ...   26653    5/3/2022
# 817          818      Adelle  ...  108026   5/10/2017
# 76            77       Adham  ...   81702   5/21/2011
# 615          616         Adi  ...  132205   5/17/2018
# 407          408      Adiana  ...   58691   7/31/2012
# 294          295       Adore  ...   33232   10/1/2011
# 576          577       Adria  ...   53870   2/27/2021
# 212          213     Adriano  ...   72289   7/14/2018
# 228          229        Aggi  ...   67223    5/5/2013
# 522          523     Agnella  ...   30926   12/9/2010
# 481          482       Agnes  ...  128512    3/7/2018
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).drop_duplicates('first_name', keep='last')
# Out:
#      employee_id  first_name  ...  salary   hire_date
# 79            80       Abbey  ...   97926   9/19/2022
# 674          675        Abbi  ...   45023   8/26/2014
# 272          273     Abigael  ...   39350    4/4/2016
# 402          403     Abraham  ...   33019    7/6/2013
# 460          461        Adda  ...   42977   8/28/2021
# 423          424    Adelheid  ...   26653    5/3/2022
# 817          818      Adelle  ...  108026   5/10/2017
# 76            77       Adham  ...   81702   5/21/2011
# 615          616         Adi  ...  132205   5/17/2018
# 407          408      Adiana  ...   58691   7/31/2012
# 294          295       Adore  ...   33232   10/1/2011
# 576          577       Adria  ...   53870   2/27/2021
# 212          213     Adriano  ...   72289   7/14/2018
# 228          229        Aggi  ...   67223    5/5/2013
# 522          523     Agnella  ...   30926   12/9/2010
# 481          482       Agnes  ...  128512    3/7/2018
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).drop_duplicates('first_name', keep='last', ignore_index=True)
# Out:
#     employee_id  first_name  ...  salary   hire_date
# 0            80       Abbey  ...   97926   9/19/2022
# 1           675        Abbi  ...   45023   8/26/2014
# 2           273     Abigael  ...   39350    4/4/2016
# 3           403     Abraham  ...   33019    7/6/2013
# 4           461        Adda  ...   42977   8/28/2021
# 5           424    Adelheid  ...   26653    5/3/2022
# 6           818      Adelle  ...  108026   5/10/2017
# 7            77       Adham  ...   81702   5/21/2011
# 8           616         Adi  ...  132205   5/17/2018
# 9           408      Adiana  ...   58691   7/31/2012
# 10          295       Adore  ...   33232   10/1/2011
# 11          577       Adria  ...   53870   2/27/2021
# 12          213     Adriano  ...   72289   7/14/2018
# 13          229        Aggi  ...   67223    5/5/2013
# 14          523     Agnella  ...   30926   12/9/2010
# 15          482       Agnes  ...  128512    3/7/2018
# 16          611     Agnesse  ...  135815  10/29/2019
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).loc[count_df.duplicated('first_name', keep='last')]
# Out:
#      employee_id first_name  ...  salary   hire_date
# 319          320    Agnesse  ...   28162   6/23/2015
# 360          361      Ahmad  ...   45742  12/28/2016
# 65            66     Anabel  ...  137214   1/24/2013
#
# [3 rows x 10 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')
description_numerical = count_df.first_name.describe()
count_df.sort_values(['first_name','last_name'], inplace=True)
count_df.head(60).loc[~count_df.duplicated('first_name', keep='last')]
# Out:
#      employee_id  first_name  ...  salary   hire_date
# 79            80       Abbey  ...   97926   9/19/2022
# 674          675        Abbi  ...   45023   8/26/2014
# 272          273     Abigael  ...   39350    4/4/2016
# 402          403     Abraham  ...   33019    7/6/2013
# 460          461        Adda  ...   42977   8/28/2021
# 423          424    Adelheid  ...   26653    5/3/2022
# 817          818      Adelle  ...  108026   5/10/2017
# 76            77       Adham  ...   81702   5/21/2011
# 615          616         Adi  ...  132205   5/17/2018
# 407          408      Adiana  ...   58691   7/31/2012
# 294          295       Adore  ...   33232   10/1/2011
# 576          577       Adria  ...   53870   2/27/2021
# 212          213     Adriano  ...   72289   7/14/2018
# 228          229        Aggi  ...   67223    5/5/2013
# 522          523     Agnella  ...   30926   12/9/2010
# 481          482       Agnes  ...  128512    3/7/2018
# ...

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df.loc[:, 'Ages'].map(add_five)
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
# 0    30
# 1    35
# 2    40
# 3    45
# 4    50
# Name: Ages, dtype: int64

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df.loc[:, 'Ages'] = df.loc[:, 'Ages'].map(add_five)

df
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
#      Names  Ages
# 0    Alice    30
# 1      Bob    35
# 2  Charlie    40
# 3    David    45
# 4      Eva    50

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df['Ages'].map(add_five)
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
# 0    30
# 1    35
# 2    40
# 3    45
# 4    50
# Name: Ages, dtype: int64

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df["Ages"] = df['Ages'].map(add_five)

df
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
#      Names  Ages
# 0    Alice    30
# 1      Bob    35
# 2  Charlie    40
# 3    David    45
# 4      Eva    50

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df['Ages'].apply(add_five)

df
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45

# %%
import pandas as pd

data = {
    "Names": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Ages": [25, 30, 35, 40, 45]
}

df = pd.DataFrame(data)

def add_five(x):
    return x + 5

print(df)

df['Ages'] = df['Ages'].apply(add_five)

df
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
# 3    David    40
# 4      Eva    45
#      Names  Ages
# 0    Alice    30
# 1      Bob    35
# 2  Charlie    40
# 3    David    45
# 4      Eva    50

# %%
df
# Out:
#      Names  Ages
# 0    Alice    30
# 1      Bob    35
# 2  Charlie    40
# 3    David    45
# 4      Eva    50

# %%
for i in df:
    print(i)
# Out:
# Names
# Ages

# %%
for i in df.index:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in df.columns:
    print(i)
# Out:
# Names
# Ages

# %%
for i in df.values:
    print(i)
# Out:
# ['Alice' 30]
# ['Bob' 35]
# ['Charlie' 40]
# ['David' 45]
# ['Eva' 50]

# %%
for i in df.Names:
    print(i)
# Out:
# Alice
# Bob
# Charlie
# David
# Eva

# %%
for i in df.Ages:
    print(i)
# Out:
# 30
# 35
# 40
# 45
# 50

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

average_salary = count_df.salary.mean()

print(average_salary)

count_df.salary.map(lambda x: x-average_salary)
# Out:
# 83760.086
# 0     -16118.086
# 1      55309.914
# 2      35454.914
# 3      48440.914
# 4      -2696.086
#          ...
# 995    52431.914
# 996    -2174.086
# 997   -46029.086
# 998    -2022.086
# 999   -55736.086
# Name: salary, Length: 1000, dtype: float64

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

average_salary = count_df.salary.mean()

print(average_salary)

count_df.salary.apply(lambda x: x-average_salary)
# Out:
# 83760.086
# 0     -16118.086
# 1      55309.914
# 2      35454.914
# 3      48440.914
# 4      -2696.086
#          ...
# 995    52431.914
# 996    -2174.086
# 997   -46029.086
# 998    -2022.086
# 999   -55736.086
# Name: salary, Length: 1000, dtype: float64

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')


average_salary = count_df.salary.mean() 

def subtract(row):
    row.salary = row.salary - average_salary
    return row


count_df.apply(subtract, axis='columns')
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')


average_salary = count_df.salary.mean() 

def subtract(row):
    row.salary = row.salary - average_salary
    return row


count_df.apply(subtract, axis=1)
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')


average_salary = count_df.salary.mean() 

def subtract(row):
    row.salary = row.salary - average_salary
    return row[['first_name','salary']]


count_df.apply(subtract, axis = 'columns')
# Out:
#     first_name     salary
# 0      Juanita -16118.086
# 1           My  55309.914
# 2     Chalmers  35454.914
# 3       Burton  48440.914
# 4      Delcine  -2696.086
# ..         ...        ...
# 995     Ardisj  52431.914
# 996    Lyndsay  -2174.086
# 997      Casar -46029.086
# 998    Aloisia  -2022.086
# 999      Kalli -55736.086
#
# [1000 rows x 2 columns]

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')


average_salary = count_df.salary.mean() 

def subtract(row):
    row.salary = row.salary - average_salary
    return row.loc['first_name':'salary']


count_df.apply(subtract, axis = 'columns')
# Out:
#     first_name     last_name  age                              email  \
# 0      Juanita      Shurrock   40               jshurrock0@cisco.com
# 1           My  Brackenridge   49       mbrackenridge1@xinhuanet.com
# 2     Chalmers       Puffett   22           cpuffett2@technorati.com
# 3       Burton      Trubshaw   65      btrubshaw3@barnesandnoble.com
# 4      Delcine      Palatini   24               dpalatini4@wufoo.com
# ..         ...           ...  ...                                ...
# 995     Ardisj     Furminger   34  afurmingerrn@pagesperso-orange.fr
# 996    Lyndsay       McVicar   30             lmcvicarro@behance.net
# 997      Casar        Ghiron   49                 cghironrp@nasa.gov
# 998    Aloisia        Jerome   44         ajeromerq@reverbnation.com
# 999      Kalli       Bramsen   26                 kbramsenrr@ihg.com
#
#            country postal_code                             job_title  \
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')


average_salary = count_df.salary.mean() 

def subtract(row):
    row.salary = row.salary - average_salary
    return row.loc[['first_name','salary']]


count_df.apply(subtract, axis = 'columns')
# Out:
#     first_name     salary
# 0      Juanita -16118.086
# 1           My  55309.914
# 2     Chalmers  35454.914
# 3       Burton  48440.914
# 4      Delcine  -2696.086
# ..         ...        ...
# 995     Ardisj  52431.914
# 996    Lyndsay  -2174.086
# 997      Casar -46029.086
# 998    Aloisia  -2022.086
# 999      Kalli -55736.086
#
# [1000 rows x 2 columns]
