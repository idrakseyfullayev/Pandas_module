# %%
import pandas as pd

data = {"A": [1, 2, 3, 4, 5], "B": [10, 20, 30, 40, 50]}

df = pd.DataFrame(data=data)
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
df["C"] = df["A"] + 100
df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  20  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
df["B"] = df["B"] + 10 
df
# Out:
#    A   B    C
# 0  1  20  101
# 1  2  30  102
# 2  3  40  103
# 3  4  50  104
# 4  5  60  105

# %%
import pandas as pd

data = {"A": [1, 2, 3, 4, 5], "B": [10, 20, 30, 40, 50]}

df = pd.DataFrame(data=data)
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
def add_new_column(x):
    return x + 100

df["C"] = df["A"].map(add_new_column)

df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  20  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
import pandas as pd

data = {"A": [1, 2, 3, 4, 5], "B": [10, 20, 30, 40, 50]}

df = pd.DataFrame(data=data)
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
def add_new_column(x):
    return x.A + 100

df["C"] = df.apply(add_new_column, axis=1)

df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  20  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def add_100_dollar(x):
    if x.age >= 40:
        x.salary = x.salary + 100
    return x

count_df = count_df.apply(add_100_dollar, axis=1)

count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              1    Juanita      Shurrock   40
# 1              2         My  Brackenridge   49
# 2              3   Chalmers       Puffett   22
# 3              4     Burton      Trubshaw   65
# 4              5    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995          996     Ardisj     Furminger   34
# 996          997    Lyndsay       McVicar   30
# 997          998      Casar        Ghiron   49
# 998          999    Aloisia        Jerome   44
# 999         1000      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
import pandas as pd

data = {"A": [1, 2, 3, 4, 5], "B": [10, 20, 30, 40, 50]}

df = pd.DataFrame(data=data)

def add_new_column(x):
    return x + 100

df["C"] = df["A"].map(add_new_column)

df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  20  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
df.groupby('B').count()
# Out:
#     A  C
# B
# 10  1  1
# 20  1  1
# 30  1  1
# 40  1  1
# 50  1  1

# %%
df.loc[df.B == 20, "B"] = 10
df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  10  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
df.groupby('B').count()
# Out:
#     A  C
# B
# 10  2  2
# 30  1  1
# 40  1  1
# 50  1  1

# %%
df.groupby('B').sum()
# Out:
#     A    C
# B
# 10  3  203
# 30  3  103
# 40  4  104
# 50  5  105

# %%
df.groupby('B').sum().loc[10:10]
# Out:
#     A    C
# B
# 10  3  203

# %%
df[df.B==10].groupby('B').sum()
# Out:
#     A    C
# B
# 10  3  203

# %%
df
# Out:
#    A   B    C
# 0  1  10  101
# 1  2  10  102
# 2  3  30  103
# 3  4  40  104
# 4  5  50  105

# %%
df.loc[:, 'C':"C"].groupby(df.B).sum()
# Out:
#       C
# B
# 10  203
# 30  103
# 40  104
# 50  105

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def emp_id(x):
    if x.age < 30:
        x.employee_id = 1
    elif x.age > 30 and x.age < 45:
        x.employee_id = 2
    else:
        x.employee_id = 3
     
    return x

count_df = count_df.apply(emp_id, axis=1)

count_df
# Out:
#      employee_id first_name     last_name  age  \
# 0              2    Juanita      Shurrock   40
# 1              3         My  Brackenridge   49
# 2              1   Chalmers       Puffett   22
# 3              3     Burton      Trubshaw   65
# 4              1    Delcine      Palatini   24
# ..           ...        ...           ...  ...
# 995            2     Ardisj     Furminger   34
# 996            3    Lyndsay       McVicar   30
# 997            3      Casar        Ghiron   49
# 998            2    Aloisia        Jerome   44
# 999            1      Kalli       Bramsen   26
#
#                                  email        country postal_code  \
# 0                 jshurrock0@cisco.com      Indonesia         NaN
# 1         mbrackenridge1@xinhuanet.com  United States       36641
# 2             cpuffett2@technorati.com      Indonesia         NaN
# 3        btrubshaw3@barnesandnoble.com          China         NaN
# ...

# %%
count_df.loc[:, "salary":"salary"].groupby(count_df.loc[:, "employee_id"]).sum()
# Out:
#                salary
# employee_id
# 1            20795406
# 2            25207514
# 3            37757166

# %%
count_df.loc[count_df.employee_id==1, "salary":"salary"].groupby(count_df["employee_id"]).sum()
# Out:
#                salary
# employee_id
# 1            20795406

# %%
count_df.loc[count_df.employee_id==3, "salary":"salary"].groupby(count_df["employee_id"]).sum()
# Out:
#                salary
# employee_id
# 3            37757166

# %%
count_df.loc[count_df['employee_id']==1, ['employee_id', 'salary']]
# Out:
#      employee_id  salary
# 2              1  119215
# 4              1   81064
# 5              1   69431
# 6              1  134551
# 9              1  149744
# ..           ...     ...
# 982            1   62143
# 985            1   40574
# 990            1   87227
# 994            1   79845
# 999            1   28024
#
# [243 rows x 2 columns]

# %%
count_df.groupby("employee_id")[['salary', 'age']].sum()
# Out:
#                salary    age
# employee_id
# 1            20795406   5898
# 2            25207514  11236
# 3            37757166  24625

# %%
count_df.groupby("employee_id").sum().loc[:, ['salary', 'age']]
# Out:
#                salary    age
# employee_id
# 1            20795406   5898
# 2            25207514  11236
# 3            37757166  24625

# %%
count_df.groupby("employee_id")[["salary"]].mean()
# Out:
#                    salary
# employee_id
# 1            85577.802469
# 2            84873.784512
# 3            82080.795652

# %%
import pandas as pd

count_df = pd.read_csv(r'C:\Users\dell\Desktop\img\money.csv')

def emp_id(x):
    if x.age < 30:
        x.employee_id = 1
    elif x.age > 30 and x.age < 45:
        x.employee_id = 2
    else:
        x.employee_id = 3
     
    return x

count_df = count_df.apply(emp_id, axis=1)

count_df_1 = count_df.head(5)

count_df_2 = count_df[10:15]

count_df_1
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
#
#          country postal_code                             job_title  salary  \
# 0      Indonesia         NaN                       Project Manager   67642
# 1  United States       36641  Business Systems Development Analyst  139070
# 2      Indonesia         NaN                  Software Engineer II  119215
# 3          China         NaN                         Social Worker  132201
# 4   South Africa        1932                       Media Manager I   81064
#
#     hire_date
# 0  12/10/2012
# 1   5/24/2010
# ...

# %%
count_df_2
# Out:
#     employee_id first_name   last_name  age                      email  \
# 10            1      Ariel      Demelt   25           ademelta@cnn.com
# 11            3   Timothee  Gunningham   46       tgunninghamb@cnn.com
# 12            2     Sheela  Bladesmith   33     sbladesmithc@jimdo.com
# 13            3       Alva     Faragan   49    afaragand@bloglovin.com
# 14            1     Saleem     Twining   23  stwininge@dailymotion.com
#
#         country postal_code                  job_title  salary   hire_date
# 10     Portugal    2380-506         Analyst Programmer  133132    5/1/2013
# 11     Pakistan       50730    Accounting Assistant IV   33107   11/1/2012
# 12  North Korea         NaN      Chief Design Engineer   97160  11/24/2010
# 13  Netherlands        1509  Account Representative II  114231  11/10/2021
# 14       Russia      663716           Technical Writer  117925  11/13/2016

# %%
pd.concat([count_df_1, count_df_2])
# Out:
#     employee_id first_name     last_name  age                          email  \
# 0             2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1             3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2             1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3             3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4             1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 10            1      Ariel        Demelt   25               ademelta@cnn.com
# 11            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 12            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 13            3       Alva       Faragan   49        afaragand@bloglovin.com
# 14            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#           country postal_code                             job_title  salary  \
# ...

# %%
pd.concat([count_df_1, count_df_2], ignore_index=True)
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code                             job_title  salary  \
# ...

# %%
count_df_merged = pd.concat([count_df_1, count_df_2], ignore_index=True)
count_df_merged
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code                             job_title  salary  \
# ...

# %%
count_df_merged.groupby("employee_id").count()
# Out:
#              first_name  last_name  age  email  country  postal_code  \
# employee_id
# 1                     4          4    4      4        4            3
# 2                     2          2    2      2        2            0
# 3                     4          4    4      4        4            3
#
#              job_title  salary  hire_date
# employee_id
# 1                    4       4          4
# 2                    2       2          2
# 3                    4       4          4

# %%
count_df_merged.groupby("employee_id")[["salary"]].sum()
# Out:
#              salary
# employee_id
# 1            451336
# 2            164802
# 3            418609

# %%
count_df_merged.groupby("employee_id")[["salary"]].sum().loc[1:1]
# Out:
#              salary
# employee_id
# 1            451336

# %%
count_df_merged[["salary"]].groupby(count_df_merged["employee_id"]).sum()
# Out:
#              salary
# employee_id
# 1            451336
# 2            164802
# 3            418609

# %%
count_df_merged[["salary"]].groupby(count_df_merged["employee_id"]).sum().loc[2:2]
# Out:
#              salary
# employee_id
# 2            164802

# %%
count_df_merged.groupby("employee_id")[["salary"]].max()
# Out:
#              salary
# employee_id
# 1            133132
# 2             97160
# 3            139070

# %%
count_df_merged.groupby("employee_id")[["salary"]].min()
# Out:
#              salary
# employee_id
# 1             81064
# 2             67642
# 3             33107

# %%
count_df_merged
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code                             job_title  salary  \
# ...

# %%
count_df_merged.drop("job_title", axis=1)
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code  salary   hire_date
# 0      Indonesia         NaN   67642  12/10/2012
# ...

# %%
count_df_merged.drop(columns="job_title")
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code  salary   hire_date
# 0      Indonesia         NaN   67642  12/10/2012
# ...

# %%
count_df_merged.drop(columns = ["job_title", 'email'])
# Out:
#    employee_id first_name     last_name  age        country postal_code  \
# 0            2    Juanita      Shurrock   40      Indonesia         NaN
# 1            3         My  Brackenridge   49  United States       36641
# 2            1   Chalmers       Puffett   22      Indonesia         NaN
# 3            3     Burton      Trubshaw   65          China         NaN
# 4            1    Delcine      Palatini   24   South Africa        1932
# 5            1      Ariel        Demelt   25       Portugal    2380-506
# 6            3   Timothee    Gunningham   46       Pakistan       50730
# 7            2     Sheela    Bladesmith   33    North Korea         NaN
# 8            3       Alva       Faragan   49    Netherlands        1509
# 9            1     Saleem       Twining   23         Russia      663716
#
#    salary   hire_date
# 0   67642  12/10/2012
# 1  139070   5/24/2010
# 2  119215   11/8/2011
# 3  132201   10/4/2015
# 4   81064    7/9/2018
# 5  133132    5/1/2013
# ...

# %%
count_df_merged.drop(columns = count_df_merged.loc[:, 'email':"job_title"])
# Out:
#    employee_id first_name     last_name  age  salary   hire_date
# 0            2    Juanita      Shurrock   40   67642  12/10/2012
# 1            3         My  Brackenridge   49  139070   5/24/2010
# 2            1   Chalmers       Puffett   22  119215   11/8/2011
# 3            3     Burton      Trubshaw   65  132201   10/4/2015
# 4            1    Delcine      Palatini   24   81064    7/9/2018
# 5            1      Ariel        Demelt   25  133132    5/1/2013
# 6            3   Timothee    Gunningham   46   33107   11/1/2012
# 7            2     Sheela    Bladesmith   33   97160  11/24/2010
# 8            3       Alva       Faragan   49  114231  11/10/2021
# 9            1     Saleem       Twining   23  117925  11/13/2016

# %%
count_df_merged.drop(index=0, columns='hire_date')
# Out:
#    employee_id first_name     last_name  age                          email  \
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 2            1   Chalmers       Puffett   22       cpuffett2@technorati.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code                             job_title  salary
# 1  United States       36641  Business Systems Development Analyst  139070
# ...

# %%
count_df_merged.drop(index = 1)
# Out:
#    employee_id first_name   last_name  age                          email  \
# 0            2    Juanita    Shurrock   40           jshurrock0@cisco.com
# 2            1   Chalmers     Puffett   22       cpuffett2@technorati.com
# 3            3     Burton    Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine    Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel      Demelt   25               ademelta@cnn.com
# 6            3   Timothee  Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela  Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva     Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem     Twining   23      stwininge@dailymotion.com
#
#         country postal_code                  job_title  salary   hire_date
# 0     Indonesia         NaN            Project Manager   67642  12/10/2012
# 2     Indonesia         NaN       Software Engineer II  119215   11/8/2011
# ...

# %%
count_df_merged.drop([0, 1])
# Out:
#    employee_id first_name   last_name  age                          email  \
# 2            1   Chalmers     Puffett   22       cpuffett2@technorati.com
# 3            3     Burton    Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine    Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel      Demelt   25               ademelta@cnn.com
# 6            3   Timothee  Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela  Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva     Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem     Twining   23      stwininge@dailymotion.com
#
#         country postal_code                  job_title  salary   hire_date
# 2     Indonesia         NaN       Software Engineer II  119215   11/8/2011
# 3         China         NaN              Social Worker  132201   10/4/2015
# 4  South Africa        1932            Media Manager I   81064    7/9/2018
# ...

# %%
count_df_merged.drop(count_df_merged[count_df_merged['age'] == 22].index)
# Out:
#    employee_id first_name     last_name  age                          email  \
# 0            2    Juanita      Shurrock   40           jshurrock0@cisco.com
# 1            3         My  Brackenridge   49   mbrackenridge1@xinhuanet.com
# 3            3     Burton      Trubshaw   65  btrubshaw3@barnesandnoble.com
# 4            1    Delcine      Palatini   24           dpalatini4@wufoo.com
# 5            1      Ariel        Demelt   25               ademelta@cnn.com
# 6            3   Timothee    Gunningham   46           tgunninghamb@cnn.com
# 7            2     Sheela    Bladesmith   33         sbladesmithc@jimdo.com
# 8            3       Alva       Faragan   49        afaragand@bloglovin.com
# 9            1     Saleem       Twining   23      stwininge@dailymotion.com
#
#          country postal_code                             job_title  salary  \
# 0      Indonesia         NaN                       Project Manager   67642
# ...

# %%
count_df_merged[count_df_merged['age'] == 22].index
# Out:
# Index([2], dtype='int64')

# %%
count_df_merged['age'] == 22
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: age, dtype: bool

# %%
# Quick Examples of dropping rows with condition

# Example 1: Using drop() to delete rows based on column value
df.drop(df[df['Fee'] >= 24000].index, inplace = True)

# Example 2: Remove rows
df2 = df[df.Fee >= 24000]

# Example 3: If you have space in column name
# Specify column name with in single quotes
df2 = df[df['column name']]

# Example 4: Using loc[]
df2 = df.loc[df["Fee"] >= 24000 ]

# Example 5: Delete rows based on multiple column value
df2 = df[ (df['Fee'] >= 22000) & (df['Discount'] == 2300)]

# Example 6: Drop rows with None/NaN
df2 = df[df.Discount.notnull()]

# %%
midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],
                             ['speed', 'weight', 'length']],
                     codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
                            [0, 1, 2, 0, 1, 2, 0, 1, 2]])
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                  data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
                        [250, 150], [1.5, 0.8], [320, 250],
                        [1, 0.8], [0.3, 0.2]])
df
# Out:
#                  big  small
# llama  speed    45.0   30.0
#        weight  200.0  100.0
#        length    1.5    1.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
#        length    1.5    0.8
# falcon speed   320.0  250.0
#        weight    1.0    0.8
#        length    0.3    0.2

# %%
df.drop(index='length', level=1)
# Out:
#                  big  small
# llama  speed    45.0   30.0
#        weight  200.0  100.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
# falcon speed   320.0  250.0
#        weight    1.0    0.8
