# %%
import pandas as pd

data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago
# 4      Eva   45        Seattle

# %%
import pandas as pd

data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data)
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 10
# ...

# %%
import pandas as pd

data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data)
print(df)
df.loc[0]
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago
# 4      Eva   45        Seattle
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data)
print(df)
df.iloc[0]
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago
# 4      Eva   45        Seattle
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.iloc[0]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# Name       Alice
# Age           25
# City    New York
# Name: A, dtype: object

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.iloc["E"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 12
#      10 df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
#      11 print(df)
# ---> 12 df.iloc["E"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1653, in _iLocIndexer._getitem_axis(self, key, axis)
#    1651 key = item_from_zerodim(key)
#    1652 if not is_integer(key):
# ...

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["E"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# Name        Eva
# Age          45
# City    Seattle
# Name: E, dtype: object

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df["E"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df["Name"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# A      Alice
# B        Bob
# C    Charlie
# D      David
# E        Eva
# Name: Name, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
type(df.loc["E"])
# Out:
# pandas.core.series.Series

# %%
df["Age"]
# Out:
# A    25
# B    30
# C    35
# D    40
# E    45
# Name: Age, dtype: int64

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["C"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# Name        Charlie
# Age              35
# City    Los Angeles
# Name: C, dtype: object

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.iloc[1:3]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
#       Name  Age           City
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.iloc[1, 0]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# 'Bob'

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.iloc[1, 2]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# 'San Francisco'

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["A":"B"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
#     Name  Age           City
# A  Alice   25       New York
# B    Bob   30  San Francisco

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B":"D"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
#       Name  Age           City
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B", "City"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# 'San Francisco'

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B":"D", "City"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# B    San Francisco
# C      Los Angeles
# D          Chicago
# Name: City, dtype: object

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B":"D", "Name":"City"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
#       Name  Age           City
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B":"D", "Name":"Age"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
#       Name  Age
# B      Bob   30
# C  Charlie   35
# D    David   40

# %%
import pandas as pd


data = {
    'Name': ['Alice', "Bob", "Charlie", 'David', 'Eva'],
    "Age": [25, 30, 35, 40 , 45],
    "City": ["New York", "San Francisco", 'Los Angeles', "Chicago", "Seattle"]
}

df = pd.DataFrame(data=data, index=['A', "B", "C", "D", "E"])
print(df)
df.loc["B", "Name":"Age"]
# Out:
#       Name  Age           City
# A    Alice   25       New York
# B      Bob   30  San Francisco
# C  Charlie   35    Los Angeles
# D    David   40        Chicago
# E      Eva   45        Seattle
# Name    Bob
# Age      30
# Name: B, dtype: object

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts
# Out:
#           username  phone_number  \
# 0          jfound0  730-393-9220
# 1          gsoule1  244-674-2095
# 2       ehendrich2  324-800-7471
# 3        rkiernan3  874-302-6761
# 4           bcopp4  270-836-3899
# ..             ...           ...
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio   last_seen  \
# 0    Vestibulum quam sapien, varius ut, blandit non...   5/12/2021
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...  11/23/2022
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...   3/11/2022
# 3    Duis consequat dui nec nisi volutpat eleifend....   3/23/2022
# 4    Curabitur in libero ut massa volutpat convalli...  12/29/2020
# ..                                                 ...         ...
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...   1/11/2021
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.tail(5)
# Out:
#           username  phone_number  \
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio   last_seen  \
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...   1/11/2021
# 996  Suspendisse potenti. In eleifend quam a odio. ...    3/1/2021
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...  10/10/2020
# 998  Quisque porta volutpat erat. Quisque erat eros...  10/12/2022
# 999  Cum sociis natoque penatibus et magnis dis par...  12/23/2020
#
#      is_verified  is_private  total_messages last_message_date  is_online
# 995         True       False            5693         3/20/2021       True
# 996         True        True            5394         11/7/2020       True
# 997         True        True            3473          3/9/2022      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.iloc[-5:]
# Out:
#           username  phone_number  \
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio   last_seen  \
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...   1/11/2021
# 996  Suspendisse potenti. In eleifend quam a odio. ...    3/1/2021
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...  10/10/2020
# 998  Quisque porta volutpat erat. Quisque erat eros...  10/12/2022
# 999  Cum sociis natoque penatibus et magnis dis par...  12/23/2020
#
#      is_verified  is_private  total_messages last_message_date  is_online
# 995         True       False            5693         3/20/2021       True
# 996         True        True            5394         11/7/2020       True
# 997         True        True            3473          3/9/2022      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.loc[:, 'bio']
# Out:
# 0      Vestibulum quam sapien, varius ut, blandit non...
# 1      Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2      Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3      Duis consequat dui nec nisi volutpat eleifend....
# 4      Curabitur in libero ut massa volutpat convalli...
#                              ...
# 995    Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996    Suspendisse potenti. In eleifend quam a odio. ...
# 997    Fusce posuere felis sed lacus. Morbi sem mauri...
# 998    Quisque porta volutpat erat. Quisque erat eros...
# 999    Cum sociis natoque penatibus et magnis dis par...
# Name: bio, Length: 1000, dtype: object

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts['bio']
# Out:
# 0      Vestibulum quam sapien, varius ut, blandit non...
# 1      Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2      Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3      Duis consequat dui nec nisi volutpat eleifend....
# 4      Curabitur in libero ut massa volutpat convalli...
#                              ...
# 995    Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996    Suspendisse potenti. In eleifend quam a odio. ...
# 997    Fusce posuere felis sed lacus. Morbi sem mauri...
# 998    Quisque porta volutpat erat. Quisque erat eros...
# 999    Cum sociis natoque penatibus et magnis dis par...
# Name: bio, Length: 1000, dtype: object

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.loc[1:5, 'phone_number':'bio']
# Out:
#    phone_number                                                bio
# 1  244-674-2095  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2  324-800-7471  Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3  874-302-6761  Duis consequat dui nec nisi volutpat eleifend....
# 4  270-836-3899  Curabitur in libero ut massa volutpat convalli...
# 5  287-651-4316  Sed sagittis. Nam congue, risus semper porta v...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.loc[:, 'username':'bio']
# Out:
#           username  phone_number  \
# 0          jfound0  730-393-9220
# 1          gsoule1  244-674-2095
# 2       ehendrich2  324-800-7471
# 3        rkiernan3  874-302-6761
# 4           bcopp4  270-836-3899
# ..             ...           ...
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio
# 0    Vestibulum quam sapien, varius ut, blandit non...
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3    Duis consequat dui nec nisi volutpat eleifend....
# 4    Curabitur in libero ut massa volutpat convalli...
# ..                                                 ...
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996  Suspendisse potenti. In eleifend quam a odio. ...
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

telegram_accounts.set_index('username')
# Out:
#                phone_number  \
# username
# jfound0        730-393-9220
# gsoule1        244-674-2095
# ehendrich2     324-800-7471
# rkiernan3      874-302-6761
# bcopp4         270-836-3899
# ...                     ...
# delcouxrn      599-998-2051
# cleadbeaterro  133-487-1114
# lbaynomrp      847-815-7187
# sarntzenrq     650-129-3220
# rkingcottrr    433-656-5751
#
#                                                              bio   last_seen  \
# username
# jfound0        Vestibulum quam sapien, varius ut, blandit non...   5/12/2021
# gsoule1        Proin eu mi. Nulla ac enim. In tempor, turpis ...  11/23/2022
# ehendrich2     Mauris enim leo, rhoncus sed, vestibulum sit a...   3/11/2022
# rkiernan3      Duis consequat dui nec nisi volutpat eleifend....   3/23/2022
# bcopp4         Curabitur in libero ut massa volutpat convalli...  12/29/2020
# ...                                                          ...         ...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

telegram_accounts.set_index('phone_number')
# Out:
#                    username  \
# phone_number
# 730-393-9220        jfound0
# 244-674-2095        gsoule1
# 324-800-7471     ehendrich2
# 874-302-6761      rkiernan3
# 270-836-3899         bcopp4
# ...                     ...
# 599-998-2051      delcouxrn
# 133-487-1114  cleadbeaterro
# 847-815-7187      lbaynomrp
# 650-129-3220     sarntzenrq
# 433-656-5751    rkingcottrr
#
#                                                             bio   last_seen  \
# phone_number
# 730-393-9220  Vestibulum quam sapien, varius ut, blandit non...   5/12/2021
# 244-674-2095  Proin eu mi. Nulla ac enim. In tempor, turpis ...  11/23/2022
# 324-800-7471  Mauris enim leo, rhoncus sed, vestibulum sit a...   3/11/2022
# 874-302-6761  Duis consequat dui nec nisi volutpat eleifend....   3/23/2022
# 270-836-3899  Curabitur in libero ut massa volutpat convalli...  12/29/2020
# ...                                                         ...         ...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

telegram_accounts.loc[telegram_accounts.is_verified==True]
# Out:
#           username  phone_number  \
# 2       ehendrich2  324-800-7471
# 6         pbowley6  381-752-8649
# 7        etooting7  514-659-4184
# 8        talforde8  596-111-1142
# 10      hkalinskya  994-997-9390
# ..             ...           ...
# 992    smacavddyrk  425-439-6423
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
#
#                                                    bio   last_seen  \
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...   3/11/2022
# 6    Mauris enim leo, rhoncus sed, vestibulum sit a...   3/10/2021
# 7    Duis consequat dui nec nisi volutpat eleifend....    7/4/2022
# 8    Curabitur in libero ut massa volutpat convalli...    8/6/2020
# 10   Duis consequat dui nec nisi volutpat eleifend....   6/12/2021
# ..                                                 ...         ...
# 992  Aliquam quis turpis eget elit sodales sceleris...   4/24/2020
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

telegram_accounts.loc[telegram_accounts.is_verified]
# Out:
#           username  phone_number  \
# 2       ehendrich2  324-800-7471
# 6         pbowley6  381-752-8649
# 7        etooting7  514-659-4184
# 8        talforde8  596-111-1142
# 10      hkalinskya  994-997-9390
# ..             ...           ...
# 992    smacavddyrk  425-439-6423
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
#
#                                                    bio   last_seen  \
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...   3/11/2022
# 6    Mauris enim leo, rhoncus sed, vestibulum sit a...   3/10/2021
# 7    Duis consequat dui nec nisi volutpat eleifend....    7/4/2022
# 8    Curabitur in libero ut massa volutpat convalli...    8/6/2020
# 10   Duis consequat dui nec nisi volutpat eleifend....   6/12/2021
# ..                                                 ...         ...
# 992  Aliquam quis turpis eget elit sodales sceleris...   4/24/2020
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

telegram_accounts.loc[telegram_accounts.is_verified==False]
# Out:
#         username  phone_number  \
# 0        jfound0  730-393-9220
# 1        gsoule1  244-674-2095
# 3      rkiernan3  874-302-6761
# 4         bcopp4  270-836-3899
# 5      adurrant5  287-651-4316
# ..           ...           ...
# 990    dcrudgeri  828-160-5337
# 991   pgarrattrj  193-514-1841
# 993  wkimberlyrl  172-353-9166
# 994      fmeusrm  263-413-2939
# 999  rkingcottrr  433-656-5751
#
#                                                    bio   last_seen  \
# 0    Vestibulum quam sapien, varius ut, blandit non...   5/12/2021
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...  11/23/2022
# 3    Duis consequat dui nec nisi volutpat eleifend....   3/23/2022
# 4    Curabitur in libero ut massa volutpat convalli...  12/29/2020
# 5    Sed sagittis. Nam congue, risus semper porta v...    7/9/2022
# ..                                                 ...         ...
# 990  Cum sociis natoque penatibus et magnis dis par...   10/2/2022
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
telegram_accounts.loc[check_name_and_lenth_verified]
# Out:
#         username  phone_number  \
# 0        jfound0  730-393-9220
# 1        gsoule1  244-674-2095
# 3      rkiernan3  874-302-6761
# 4         bcopp4  270-836-3899
# 5      adurrant5  287-651-4316
# ..           ...           ...
# 990    dcrudgeri  828-160-5337
# 991   pgarrattrj  193-514-1841
# 993  wkimberlyrl  172-353-9166
# 994      fmeusrm  263-413-2939
# 999  rkingcottrr  433-656-5751
#
#                                                    bio   last_seen  \
# 0    Vestibulum quam sapien, varius ut, blandit non...   5/12/2021
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...  11/23/2022
# 3    Duis consequat dui nec nisi volutpat eleifend....   3/23/2022
# 4    Curabitur in libero ut massa volutpat convalli...  12/29/2020
# 5    Sed sagittis. Nam congue, risus semper porta v...    7/9/2022
# ..                                                 ...         ...
# 990  Cum sociis natoque penatibus et magnis dis par...   10/2/2022
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified]
len(not_verified)
# Out:
# 505

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified]
len(not_verified.head())
# Out:
# 5

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified]
not_verified.head()
# Out:
#     username  phone_number                                                bio  \
# 0    jfound0  730-393-9220  Vestibulum quam sapien, varius ut, blandit non...
# 1    gsoule1  244-674-2095  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3  rkiernan3  874-302-6761  Duis consequat dui nec nisi volutpat eleifend....
# 4     bcopp4  270-836-3899  Curabitur in libero ut massa volutpat convalli...
# 5  adurrant5  287-651-4316  Sed sagittis. Nam congue, risus semper porta v...
#
#     last_seen  is_verified  is_private  total_messages last_message_date  \
# 0   5/12/2021        False        True            9285         8/12/2020
# 1  11/23/2022        False       False            4680         1/26/2020
# 3   3/23/2022        False       False            9182         6/11/2021
# 4  12/29/2020        False       False            6521         8/21/2021
# 5    7/9/2022        False       False            1102         8/24/2021
#
#    is_online
# 0      False
# 1       True
# 3       True
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_online']]
not_verified
# Out:
#         username                                                bio  is_online
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...      False
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...       True
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....       True
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...      False
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...      False
# ..           ...                                                ...        ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...      False
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.      False
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...       True
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...      False
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...       True
#
# [505 rows x 3 columns]

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.loc[:, 'username': 'bio']
# Out:
#           username  phone_number  \
# 0          jfound0  730-393-9220
# 1          gsoule1  244-674-2095
# 2       ehendrich2  324-800-7471
# 3        rkiernan3  874-302-6761
# 4           bcopp4  270-836-3899
# ..             ...           ...
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio
# 0    Vestibulum quam sapien, varius ut, blandit non...
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3    Duis consequat dui nec nisi volutpat eleifend....
# 4    Curabitur in libero ut massa volutpat convalli...
# ..                                                 ...
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996  Suspendisse potenti. In eleifend quam a odio. ...
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.loc[:, ['username', 'phone_number', 'bio']]
# Out:
#           username  phone_number  \
# 0          jfound0  730-393-9220
# 1          gsoule1  244-674-2095
# 2       ehendrich2  324-800-7471
# 3        rkiernan3  874-302-6761
# 4           bcopp4  270-836-3899
# ..             ...           ...
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio
# 0    Vestibulum quam sapien, varius ut, blandit non...
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3    Duis consequat dui nec nisi volutpat eleifend....
# 4    Curabitur in libero ut massa volutpat convalli...
# ..                                                 ...
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996  Suspendisse potenti. In eleifend quam a odio. ...
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts[['username','phone_number','bio']]
# Out:
#           username  phone_number  \
# 0          jfound0  730-393-9220
# 1          gsoule1  244-674-2095
# 2       ehendrich2  324-800-7471
# 3        rkiernan3  874-302-6761
# 4           bcopp4  270-836-3899
# ..             ...           ...
# 995      delcouxrn  599-998-2051
# 996  cleadbeaterro  133-487-1114
# 997      lbaynomrp  847-815-7187
# 998     sarntzenrq  650-129-3220
# 999    rkingcottrr  433-656-5751
#
#                                                    bio
# 0    Vestibulum quam sapien, varius ut, blandit non...
# 1    Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 2    Mauris enim leo, rhoncus sed, vestibulum sit a...
# 3    Duis consequat dui nec nisi volutpat eleifend....
# 4    Curabitur in libero ut massa volutpat convalli...
# ..                                                 ...
# 995  Sed ante. Vivamus tortor. Duis mattis egestas ...
# 996  Suspendisse potenti. In eleifend quam a odio. ...
# 997  Fusce posuere felis sed lacus. Morbi sem mauri...
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.is_verified = True
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0           True      False
# 1           True       True
# 3           True       True
# 4           True      False
# ...

# %%
not_verified
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3          False       True
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy['is_verified']=True
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0           True      False
# 1           True       True
# 3           True       True
# 4           True      False
# ...

# %%
not_verified
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3          False       True
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[:,'is_verified']= True
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0           True      False
# 1           True       True
# 3           True       True
# 4           True      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[:,['is_verified', 'is_online']]= True, True
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0           True       True
# 1           True       True
# 3           True       True
# 4           True       True
# ...

# %%
not_verified
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3          False       True
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.is_verified==False) & (df_copy.username=='jfound0'), ['username', 'is_verified']]
# Out:
#   username  is_verified
# 0  jfound0        False

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.is_verified==False) & (df_copy.username=='jfound0'), ['username']] = 'Idrak'
df_copy
# Out:
#         username                                                bio  \
# 0          Idrak  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3          False       True
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.is_verified==False) & (df_copy.username=='jfound0'), ['username', 'is_verified']] = 'Idrak', True
df_copy
# Out:
#         username                                                bio  \
# 0          Idrak  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0           True      False
# 1          False       True
# 3          False       True
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.username=='rkiernan3') & ((df_copy.is_verified==True)|(df_copy.is_online==True)) , 
            ['username', 'is_verified', 'is_online']]
# Out:
#     username  is_verified  is_online
# 3  rkiernan3        False       True

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.username=='rkiernan3') & ((df_copy.is_verified==True)|(df_copy.is_online==True)) , 
            ['is_verified', 'is_online']] = True, False
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3           True      False
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')

check_name_and_lenth_verified = (telegram_accounts.is_verified==False) & (len(telegram_accounts.username)>10)
not_verified = telegram_accounts.loc[check_name_and_lenth_verified, ["username",'bio', 'is_verified', 'is_online']]
not_verified

df_copy = not_verified.copy()
df_copy.loc[(df_copy.username=='rkiernan3') & ((df_copy.is_verified==True)|(df_copy.is_online==True)) , 
            'is_verified':'is_online'] = True, False
df_copy
# Out:
#         username                                                bio  \
# 0        jfound0  Vestibulum quam sapien, varius ut, blandit non...
# 1        gsoule1  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 3      rkiernan3  Duis consequat dui nec nisi volutpat eleifend....
# 4         bcopp4  Curabitur in libero ut massa volutpat convalli...
# 5      adurrant5  Sed sagittis. Nam congue, risus semper porta v...
# ..           ...                                                ...
# 990    dcrudgeri  Cum sociis natoque penatibus et magnis dis par...
# 991   pgarrattrj            Fusce consequat. Nulla nisl. Nunc nisl.
# 993  wkimberlyrl  Proin eu mi. Nulla ac enim. In tempor, turpis ...
# 994      fmeusrm  Quisque porta volutpat erat. Quisque erat eros...
# 999  rkingcottrr  Cum sociis natoque penatibus et magnis dis par...
#
#      is_verified  is_online
# 0          False      False
# 1          False       True
# 3           True      False
# 4          False      False
# ...

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.columns
# Out:
# Index(['username', 'phone_number', 'bio', 'last_seen', 'is_verified',
#        'is_private', 'total_messages', 'last_message_date', 'is_online'],
#       dtype='object')

# %%
import pandas as pd

telegram_accounts = pd.read_csv(r'C:\Users\dell\Desktop\img\MOCK_DATA.csv')
telegram_accounts.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)
